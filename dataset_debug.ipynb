# %%
import glob
import os
import cv2
import numpy as np
import os


from PIL import Image
import matplotlib.pyplot as plt

# %%
normal = Image.open('./PS_Wild_train/american_football_ball.obj_asphalt_fine_cracked_dark_old.data/normal.tif')
# C:\Users\seokjub\Workspace\Universal-PS-CVPR2022\PS_Wild_train\american_football_ball.obj_asphalt_fine_cracked_dark_old.data
normal_np = np.array(normal)
plt.imshow(normal_np)
plt.colorbar()
print()

# %%
normal = Image.open('../lightdesk_dataset/train/20230323_004_owl.data/normal.tif')
# C:\Users\seokjub\Workspace\Universal-PS-CVPR2022\PS_Wild_train\american_football_ball.obj_asphalt_fine_cracked_dark_old.data
normal_np = np.array(normal)
plt.imshow(normal_np)
plt.colorbar()
print()
